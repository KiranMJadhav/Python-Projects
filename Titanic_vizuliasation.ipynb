# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('titanic')

# display head() of the dataset
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.drop("deck",axis=1,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    object
#  3   age          712 non-null    float64
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        712 non-null    category
#  9   who          712 non-null    object
#  10  adult_male   712 non-null    bool
#  11  embark_town  712 non-null    object
#  12  alive        712 non-null    object
#  13  alone        712 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 69.0+ KB

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
import numpy as np

# %%
sns.stripplot(y = 'age', x = 'sex', data = df,color='orange')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(y = 'age', x = 'sex', data = df, hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.swarmplot(y = 'fare',color='orange' ,x = 'class', data = df,hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.violinplot(y = 'age', x = 'sex', data = df,hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
plt.figure(figsize = (8,8))

# plot a pair plot
sns.pairplot(df)

# display the plot
plt.show()

# %%
plt.figure(figsize = (8,8))

# plot a pair plot
sns.pairplot(tips_data,hue='class')

# display the plot
plt.show()

# %%
sns.displot(tips_data['fare'])

# display the plot
plt.show()

# %%
sns.distplot(tips_data['fare'])

# display the plot
plt.show()

# %%
sns.kdeplot(df["age"])
plt.show()

# %%
sns.countplot(data = df, x = 'embark_town')

# display the plot
plt.show()

# %%
sns.countplot(data = df, x = 'embark_town',hue='sex')

# display the plot
plt.show()

# %%
corr_matrix = df.corr()

corr_matrix
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.356462 -0.082446 -0.015523  0.095265  0.266100
# pclass     -0.356462  1.000000 -0.365902  0.065187  0.023666 -0.552893
# age        -0.082446 -0.365902  1.000000 -0.307351 -0.187896  0.093143
# sibsp      -0.015523  0.065187 -0.307351  1.000000  0.383338  0.139860
# parch       0.095265  0.023666 -0.187896  0.383338  1.000000  0.206624
# fare        0.266100 -0.552893  0.093143  0.139860  0.206624  1.000000
# adult_male -0.551151  0.094635  0.286543 -0.313016 -0.365580 -0.177446
# alone      -0.199741  0.150576  0.195766 -0.629408 -0.577109 -0.262799
#
#             adult_male     alone
# survived     -0.551151 -0.199741
# pclass        0.094635  0.150576
# age           0.286543  0.195766
# sibsp        -0.313016 -0.629408
# parch        -0.365580 -0.577109
# fare         -0.177446 -0.262799
# adult_male    1.000000  0.400718
# alone         0.400718  1.000000

# %%
sns.heatmap(corr_matrix, annot = True)

# display the plot
plt.show()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
y=df['sex'].value_counts()
y
# Out:
# male      453
# female    259
# Name: sex, dtype: int64

# %%
x=df['embark_town']
y=df['fare']
plt.bar(x,y)
plt.show()

# %%
x=['Male','Female']
y=df['sex'].value_counts()
plt.bar(x,y)
plt.show()

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data = df, x = 'embark_town',hue='alive')

# display the plot
plt.show()

# %%
x = df['embark_town']
y = df['age']
#z = ['pclass']
#c = [(random(),random(),random(),1) for i in range(len(x))]
#c1 = [(random(),random(),random(),1) for i in range(len(x))]

# c = ['r', 'b', 'g', 'c']
width=0.2
#p=np.arange(len(x))
#p1=np.arange(len(x))+width
plt.xlabel('town', fontsize=15)
plt.ylabel('age', fontsize=15)
plt.title('Tiatnic', fontsize=20)
plt.bar(x,y, width=0.2, color='cyan', label='Popularity')
#plt.bar(y,z, width=width, color='r', label='Popularity1')

#plt.xticks(p+width/2, x, rotation=45)
#plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 14
#      12 plt.ylabel('age', fontsize=15)
#      13 plt.title('Tiatnic', fontsize=20)
# ---> 14 plt.bar(x,y, width=0.2, color='cyan', label='Popularity')
#      15 #plt.bar(y,z, width=width, color='r', label='Popularity1')
#      16
#      17 #plt.xticks(p+width/2, x, rotation=45)
#      18 #plt.legend()
#      19 plt.show()
#
# File D:\Anaconda\New folder\Lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# ...
