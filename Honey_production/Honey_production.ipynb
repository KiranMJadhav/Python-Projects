# %% [markdown]
# ## 1. Import required libraries and read the dataset.

# %%
import pandas as pd
import numpy as np

# Libraries used for visualization
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px  # pip install plotly

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 621    618000.0  2012
# 622   6050000.0  2012
# 623    838000.0  2012
# 624   8487000.0  2012
# 625   4769000.0  2012
#
# [626 rows x 8 columns]

# %% [markdown]
# ## 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df['year'] = df['year'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 39.3+ KB

# %% [markdown]
# ## 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
df['year'].unique()
# Out:
# array([1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012.])

# %%
plt.figure(figsize=(8,8))

plt.pie(df.year.value_counts(), autopct = '%.2f%%', radius = 1.1, labels = [1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
       2007., 2008., 2009., 2010., 2011., 2012],labeldistance=1.1)

# display the plot
plt.show()

# %% [markdown]
# ## 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.distplot(df['priceperlb'])

# display the plot
plt.show()

# %% [markdown]
# * We can see that th data is right skeawed.
# * We can say that the median is nearby 1.3 nearby something.

# %% [markdown]
# ## 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(x=df['numcol'], y=df['prodvalue'])  # Plots the scatter plot using two variables
plt.show()

# %% [markdown]
# * We can see some relationship between this given two variables.
# * We can see linear regression between this two variables.
# * prodvalue is increasing the number of numcol is also increasing.
# * At some point the value of numcol has been fall and some are in increasing order.

# %% [markdown]
# ## 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings

# %%
plt.figure(figsize=(10, 6))  
sns.set(style="whitegrid")  
sns.boxplot(x='year', y='prodvalue', data=df)


plt.xlabel("Year")
plt.ylabel("Production Value")
plt.title("Relationship between Year and Production Value (Boxplot)")


plt.show()

# %% [markdown]
# ## 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year'

# %%
#data=df['numcol', 'yield percol', 'total prod', 'prodvalue']
sns.pairplot(data=df, hue='year')
plt.show()

# %% [markdown]
# ## 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue'

# %%
df.corr()
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  \
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567
# year         0.008709    -0.232092  -0.055556 -0.119602    0.693984
#
#              prodvalue      year
# numcol        0.912796  0.008709
# yieldpercol   0.278977 -0.232092
# totalprod     0.907236 -0.055556
# stocks        0.728560 -0.119602
# priceperlb   -0.089567  0.693984
# prodvalue     1.000000  0.139451
# year          0.139451  1.000000

# %%
fig,ax=plt.subplots(figsize=(10,8)) # we can use also plt.figure(figsize=())
sns.heatmap(df.corr(), annot=True,fmt='.2f',ax=ax)  # plot the correlation coefficients as a heatmap
plt.show()
